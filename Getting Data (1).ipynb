# %%
import pandas as pd
import yfinance as yf

# %% [markdown]
# # **Step-1**

# %%
df = pd.read_csv("ind_nifty500list_filtered_final.csv")

# %%
df
# Out:
#                            Company Name                           Industry  \
# 0                      360 ONE WAM Ltd.                 Financial Services
# 1                        ABB India Ltd.                      Capital Goods
# 2                              ACC Ltd.             Construction Materials
# 3                  AIA Engineering Ltd.                      Capital Goods
# 4                 APL Apollo Tubes Ltd.                      Capital Goods
# ..                                  ...                                ...
# 440  Zee Entertainment Enterprises Ltd.  Media Entertainment & Publication
# 441             Zensar Technolgies Ltd.             Information Technology
# 442                         Zomato Ltd.                  Consumer Services
# 443             Zydus Lifesciences Ltd.                         Healthcare
# 444                eClerx Services Ltd.                           Services
#
#          Symbol Series     ISIN Code
# ...

# %% [markdown]
# # **Step-2**

# %%
def stockPrice(company):
    ticker = company+".NS"
    stock = yf.Ticker(ticker)

    historical_data = stock.history(start= "2022-01-10",end = "2025-03-30", interval="1d")  # Data for the past month
    historical_data.to_csv(f"stock_data/raw/{company}.csv")

# %%
for company in df["Symbol"]:
    stockPrice(company)
    print(company)
# Out:
# 360ONE
# ABB
# ACC
# AIAENG
# APLAPOLLO
# AUBANK
# AARTIIND
# AAVAS
# ABBOTINDIA
# ACE
# ADANIENT
# ADANIGREEN
# ADANIPORTS
# ADANIPOWER
# ATGL
# ABCAPITAL
# ABFRL
# ABSLAMC
# AFFLE
# AJANTPHARM
# APLLTD
# ALKEM
# ALKYLAMINE
# ALOKINDS
# AMBER
# AMBUJACEM
# ANANDRATHI
# ANANTRAJ
# ANGELONE
# APARINDS
# APOLLOHOSP
# APOLLOTYRE
# APTUS
# ASAHIINDIA
# ASHOKLEY
# ASIANPAINT
# ASTERDM
# ASTRAZEN
# ASTRAL
# ATUL
# AUROPHARMA
# AVANTIFEED
# DMART
# AXISBANK
# BASF
# BEML
# BLS
# BSE
# BAJAJ-AUTO
# BAJFINANCE
# BAJAJFINSV
# BAJAJHLDNG
# BALAMINES
# BALKRISIND
# BALRAMCHIN
# BANDHANBNK
# BANKBARODA
# BANKINDIA
# MAHABANK
# BATAINDIA
# BAYERCROP
# BERGEPAINT
# BDL
# BEL
# BHARATFORG
# BHEL
# BPCL
# BHARTIARTL
# BIOCON
# BIRLACORPN
# BSOFT
# BLUEDART
# BLUESTARCO
# BBTC
# BOSCHLTD
# BRITANNIA
# MAPMYINDIA
# CCL
# CESC
# CGPOWER
# CIEINDIA
# CRISIL
# CANFINHOME
# CANBK
# CAPLIPOINT
# CGCL
# CARBORUNIV
# CASTROLIND
# CEATLTD
# CENTRALBK
# CDSL
# CENTURYPLY
# CERA
# CHALET
# CHAMBLFERT
# ...
