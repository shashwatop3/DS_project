# %%
import dask.dataframe as dd
import pandas as pd
import pandas_ta as ta
import numpy as np
import os
import glob
import sys
from pathlib import Path
import pyarrow as pa

# %%
sector_file = 'stock_data/meta/ind_nifty500list_filtered_final.csv'
stock_sector = pd.read_csv(sector_file, dtype={'Symbol': str})
print(f"Loaded {len(stock_sector)} sector mappings")

# 2. Load Raw Stock Data
files = glob.glob('stock_data/raw/*.csv')
print(f"Found {len(files)} stock files")

dfs = []
for f in files:
    try:
        ticker = Path(f).stem
        if ticker not in stock_sector['Symbol'].values:
            print(f"Ticker {ticker} not found in sector mapping, skipping")
            continue

        # Read with date parsing and validation
        df = pd.read_csv(
            f,
            usecols=['Date', 'Close', 'Stock Splits'],
            parse_dates=['Date'],
            index_col='Date',
            dayfirst=True  # Important for non-US date formats
        )
        
        # Handle splits and calculate adjusted close
        df['Split Factor'] = (1 + df['Stock Splits']).replace(0, 1).cumprod()
        df['Adj Close'] = df['Close'] / df['Split Factor']
        
        dfs.append(df[['Adj Close']].rename(columns={'Adj Close': ticker}))
        
    except Exception as e:
        print(f"Error processing {ticker}: {str(e)}")

# 3. Create Consolidated DataFrame
if not dfs:
    raise ValueError("No valid stock data processed")

master_df = pd.concat(dfs, axis=1)
print(f"Master DataFrame shape: {master_df.shape}")

# 4. Merge with Sector Information (preserve date index)
merged_df = (
    master_df.T
    .reset_index()
    .rename(columns={'index': 'Symbol'})
    .merge(stock_sector[['Symbol', 'Industry']],  # Verify actual column name
           on='Symbol',
           how='left')
    .set_index(['Industry', 'Symbol'])
    .T
    .sort_index(axis=1)
)

# Convert index to proper datetime
merged_df.index = pd.to_datetime(merged_df.index)
print("\nFinal Merged DataFrame:")
print(f"Index: {merged_df.index.name}")
print(f"Columns: {merged_df.columns.names}")
print(f"Shape: {merged_df.shape}")
print(merged_df.head(2))
# Out:
# Loaded 445 sector mappings
# Found 501 stock files
# Ticker CELLO not found in sector mapping, skipping
# Ticker HONASA not found in sector mapping, skipping
# Ticker TBOTEK not found in sector mapping, skipping
# Ticker MANYAVAR not found in sector mapping, skipping
# Ticker RRKABEL not found in sector mapping, skipping
# Ticker IREDA not found in sector mapping, skipping
# Ticker ADANIENSOL not found in sector mapping, skipping
# Ticker SYRMA not found in sector mapping, skipping
# Ticker SIGNATURE not found in sector mapping, skipping
# Ticker INOXINDIA not found in sector mapping, skipping
# Ticker RAINBOW not found in sector mapping, skipping
# Ticker DELHIVERY not found in sector mapping, skipping
# Ticker FIVESTAR not found in sector mapping, skipping
# Ticker LLOYDSME not found in sector mapping, skipping
# Ticker JnKBANK not found in sector mapping, skipping
# Ticker INDGN not found in sector mapping, skipping
# Ticker NSLNISP not found in sector mapping, skipping
# Ticker TATATECH not found in sector mapping, skipping
# Ticker EMCURE not found in sector mapping, skipping
# Ticker MnMFIN not found in sector mapping, skipping
# Ticker GODREJIND not found in sector mapping, skipping
# Ticker DUMMYITC not found in sector mapping, skipping
# Ticker AWL not found in sector mapping, skipping
# Ticker ACI not found in sector mapping, skipping
# Ticker NETWEB not found in sector mapping, skipping
# Ticker PTCIL not found in sector mapping, skipping
# Ticker AADHARHFC not found in sector mapping, skipping
# Ticker GVTnD not found in sector mapping, skipping
# Ticker SWANENERGY not found in sector mapping, skipping
# Ticker PVRINOX not found in sector mapping, skipping
# Ticker ABREL not found in sector mapping, skipping
# Ticker KPIL not found in sector mapping, skipping
# Ticker BRIGADE not found in sector mapping, skipping
# Ticker AREnM not found in sector mapping, skipping
# Ticker CAMPUS not found in sector mapping, skipping
# Ticker BIKAJI not found in sector mapping, skipping
# Ticker TVSSCS not found in sector mapping, skipping
# Ticker AEGISLOG not found in sector mapping, skipping
# Ticker CONCORDBIO not found in sector mapping, skipping
# Ticker MnM not found in sector mapping, skipping
# Ticker PPLPHARMA not found in sector mapping, skipping
# Ticker AKUMS not found in sector mapping, skipping
# Ticker NUVAMA not found in sector mapping, skipping
# Ticker DOMS not found in sector mapping, skipping
# Ticker MANKIND not found in sector mapping, skipping
# Ticker MSUMI not found in sector mapping, skipping
# Ticker KFINTECH not found in sector mapping, skipping
# Ticker PHOENIXLTD not found in sector mapping, skipping
# Ticker MEDANTA not found in sector mapping, skipping
# Ticker 3MINDIA not found in sector mapping, skipping
# Ticker GODIGIT not found in sector mapping, skipping
# Ticker LICI not found in sector mapping, skipping
# Ticker BHARTIHEXA not found in sector mapping, skipping
# Ticker JYOTICNC not found in sector mapping, skipping
# Ticker KAYNES not found in sector mapping, skipping
# Ticker UNITDSPR not found in sector mapping, skipping
# Ticker JSWINFRA not found in sector mapping, skipping
# Ticker SBFC not found in sector mapping, skipping
# Ticker JIOFIN not found in sector mapping, skipping
# Ticker HBLENGINE not found in sector mapping, skipping
# Master DataFrame shape: (741, 441)
#
# Final Merged DataFrame:
# Index: None
# Columns: ['Industry', 'Symbol']
# Shape: (741, 441)
# Industry                  Automobile and Auto Components              \
# Symbol                                        APOLLOTYRE  ASAHIINDIA
# 2022-01-10 00:00:00+05:30                     223.718369  547.070801
# 2022-01-11 00:00:00+05:30                     223.092926  566.683289
#
# Industry                                                                       \
# Symbol                      BAJAJ-AUTO   BALKRISIND  BHARATFORG      BOSCHLTD
# 2022-01-10 00:00:00+05:30  3186.578613  2343.807373  750.056519  16433.021484
# 2022-01-11 00:00:00+05:30  3188.109131  2358.666016  752.206482  16307.836914
#
# Industry                                                                      \
# Symbol                         CEATLTD    CIEINDIA    CRAFTSMAN    EICHERMOT
# 2022-01-10 00:00:00+05:30  1125.336304  221.650330  2311.613037  2736.037354
# 2022-01-11 00:00:00+05:30  1126.414185  224.717316  2302.476807  2715.484375
#
# Industry                   ... Telecommunication                           \
# Symbol                     ...             ROUTE     TATACOMM    TEJASNET
# 2022-01-10 00:00:00+05:30  ...       1767.905151  1421.090332  446.899994
# 2022-01-11 00:00:00+05:30  ...       1817.629639  1415.016235  469.200012
#
# Industry                                Textiles                            \
# Symbol                           TTML   ALOKINDS     KPRMILL       PAGEIND
# 2022-01-10 00:00:00+05:30  276.350006  29.799999  717.887817  42242.050781
# 2022-01-11 00:00:00+05:30  290.149994  30.000000  721.382324  42243.734375
#
# Industry
# Symbol                       TRIDENT         VTL  WELSPUNLIV
# 2022-01-10 00:00:00+05:30  51.811363  515.310852  152.255203
# 2022-01-11 00:00:00+05:30  54.382526  507.546356  148.519791
#
# [2 rows x 441 columns]

# %%
merged_df.head()
# Out:
# Industry                  Automobile and Auto Components              \
# Symbol                                        APOLLOTYRE  ASAHIINDIA
# 2022-01-10 00:00:00+05:30                     223.718369  547.070801
# 2022-01-11 00:00:00+05:30                     223.092926  566.683289
# 2022-01-12 00:00:00+05:30                     224.824921  559.700073
# 2022-01-13 00:00:00+05:30                     226.075821  550.983398
# 2022-01-14 00:00:00+05:30                     222.852371  570.843506
#
# Industry                                                                       \
# Symbol                      BAJAJ-AUTO   BALKRISIND  BHARATFORG      BOSCHLTD
# 2022-01-10 00:00:00+05:30  3186.578613  2343.807373  750.056519  16433.021484
# 2022-01-11 00:00:00+05:30  3188.109131  2358.666016  752.206482  16307.836914
# 2022-01-12 00:00:00+05:30  3191.216797  2387.699463  743.215576  16419.531250
# 2022-01-13 00:00:00+05:30  3201.328369  2405.821777  750.545105  16411.558594
# 2022-01-14 00:00:00+05:30  3184.444824  2425.745361  763.347412  16495.898438
#
# Industry                                                                      \
# Symbol                         CEATLTD    CIEINDIA    CRAFTSMAN    EICHERMOT
# 2022-01-10 00:00:00+05:30  1125.336304  221.650330  2311.613037  2736.037354
# 2022-01-11 00:00:00+05:30  1126.414185  224.717316  2302.476807  2715.484375
# 2022-01-12 00:00:00+05:30  1107.895264  219.849106  2310.520508  2736.426025
# 2022-01-13 00:00:00+05:30  1116.664917  220.579315  2328.644775  2752.751953
# 2022-01-14 00:00:00+05:30  1116.615723  221.455597  2324.125977  2740.118896
#
# Industry                   ... Telecommunication                           \
# Symbol                     ...             ROUTE     TATACOMM    TEJASNET
# 2022-01-10 00:00:00+05:30  ...       1767.905151  1421.090332  446.899994
# 2022-01-11 00:00:00+05:30  ...       1817.629639  1415.016235  469.200012
# 2022-01-12 00:00:00+05:30  ...       1830.158081  1490.009155  491.000000
# 2022-01-13 00:00:00+05:30  ...       1862.771851  1478.339355  515.549988
# 2022-01-14 00:00:00+05:30  ...       1843.613159  1478.100342  509.149994
#
# Industry                                Textiles                            \
# Symbol                           TTML   ALOKINDS     KPRMILL       PAGEIND
# 2022-01-10 00:00:00+05:30  276.350006  29.799999  717.887817  42242.050781
# 2022-01-11 00:00:00+05:30  290.149994  30.000000  721.382324  42243.734375
# 2022-01-12 00:00:00+05:30  275.649994  29.000000  733.932800  42989.968750
# 2022-01-13 00:00:00+05:30  261.899994  28.750000  728.125122  42972.933594
# 2022-01-14 00:00:00+05:30  248.850006  30.049999  744.514587  43183.343750
#
# Industry
# Symbol                       TRIDENT         VTL  WELSPUNLIV
# 2022-01-10 00:00:00+05:30  51.811363  515.310852  152.255203
# 2022-01-11 00:00:00+05:30  54.382526  507.546356  148.519791
# 2022-01-12 00:00:00+05:30  57.099224  510.023132  149.615524
# 2022-01-13 00:00:00+05:30  59.912949  516.804810  153.251312
# 2022-01-14 00:00:00+05:30  62.872211  528.766113  150.611633
#
# [5 rows x 441 columns]

# %%
def calculate_sma(data, window):
    return data.rolling(window=window).mean()

def calculate_ema(data, window):
    return data.ewm(span=window, adjust=False).mean()

# %%
def calculate_bollinger_bands(data, window, num_std_dev):
    sma = calculate_sma(data, window)
    rolling_std = data.rolling(window=window).std()
    upper_band = sma + (rolling_std * num_std_dev)
    lower_band = sma - (rolling_std * num_std_dev)
    return upper_band, lower_band

# %%
def calculate_rsi(data, window):
    delta = data.diff()
    gain = delta.where(delta > 0, 0)
    loss = -delta.where(delta < 0, 0)

    avg_gain = gain.rolling(window=window).mean()
    avg_loss = loss.rolling(window=window).mean()

    rs = avg_gain / avg_loss
    rsi = 100 - (100 / (1 + rs))
    return rsi

# %%
def calculate_macd(data, fast_window, slow_window, signal_window):
    ema_fast = calculate_ema(data, fast_window)
    ema_slow = calculate_ema(data, slow_window)
    macd_line = ema_fast - ema_slow
    signal_line = macd_line.ewm(span=signal_window, adjust=False).mean()
    macd_histogram = macd_line - signal_line
    return macd_line, signal_line, macd_histogram

# %%
def approximate_atr(data, window):
    return data.diff().abs().rolling(window=window).mean()

# %%
merged_df.head()
# Out:
# Industry                  Automobile and Auto Components              \
# Symbol                                        APOLLOTYRE  ASAHIINDIA
# 2022-01-10 00:00:00+05:30                     223.718369  547.070801
# 2022-01-11 00:00:00+05:30                     223.092926  566.683289
# 2022-01-12 00:00:00+05:30                     224.824921  559.700073
# 2022-01-13 00:00:00+05:30                     226.075821  550.983398
# 2022-01-14 00:00:00+05:30                     222.852371  570.843506
#
# Industry                                                                       \
# Symbol                      BAJAJ-AUTO   BALKRISIND  BHARATFORG      BOSCHLTD
# 2022-01-10 00:00:00+05:30  3186.578613  2343.807373  750.056519  16433.021484
# 2022-01-11 00:00:00+05:30  3188.109131  2358.666016  752.206482  16307.836914
# 2022-01-12 00:00:00+05:30  3191.216797  2387.699463  743.215576  16419.531250
# 2022-01-13 00:00:00+05:30  3201.328369  2405.821777  750.545105  16411.558594
# 2022-01-14 00:00:00+05:30  3184.444824  2425.745361  763.347412  16495.898438
#
# Industry                                                                      \
# Symbol                         CEATLTD    CIEINDIA    CRAFTSMAN    EICHERMOT
# 2022-01-10 00:00:00+05:30  1125.336304  221.650330  2311.613037  2736.037354
# 2022-01-11 00:00:00+05:30  1126.414185  224.717316  2302.476807  2715.484375
# 2022-01-12 00:00:00+05:30  1107.895264  219.849106  2310.520508  2736.426025
# 2022-01-13 00:00:00+05:30  1116.664917  220.579315  2328.644775  2752.751953
# 2022-01-14 00:00:00+05:30  1116.615723  221.455597  2324.125977  2740.118896
#
# Industry                   ... Telecommunication                           \
# Symbol                     ...             ROUTE     TATACOMM    TEJASNET
# 2022-01-10 00:00:00+05:30  ...       1767.905151  1421.090332  446.899994
# 2022-01-11 00:00:00+05:30  ...       1817.629639  1415.016235  469.200012
# 2022-01-12 00:00:00+05:30  ...       1830.158081  1490.009155  491.000000
# 2022-01-13 00:00:00+05:30  ...       1862.771851  1478.339355  515.549988
# 2022-01-14 00:00:00+05:30  ...       1843.613159  1478.100342  509.149994
#
# Industry                                Textiles                            \
# Symbol                           TTML   ALOKINDS     KPRMILL       PAGEIND
# 2022-01-10 00:00:00+05:30  276.350006  29.799999  717.887817  42242.050781
# 2022-01-11 00:00:00+05:30  290.149994  30.000000  721.382324  42243.734375
# 2022-01-12 00:00:00+05:30  275.649994  29.000000  733.932800  42989.968750
# 2022-01-13 00:00:00+05:30  261.899994  28.750000  728.125122  42972.933594
# 2022-01-14 00:00:00+05:30  248.850006  30.049999  744.514587  43183.343750
#
# Industry
# Symbol                       TRIDENT         VTL  WELSPUNLIV
# 2022-01-10 00:00:00+05:30  51.811363  515.310852  152.255203
# 2022-01-11 00:00:00+05:30  54.382526  507.546356  148.519791
# 2022-01-12 00:00:00+05:30  57.099224  510.023132  149.615524
# 2022-01-13 00:00:00+05:30  59.912949  516.804810  153.251312
# 2022-01-14 00:00:00+05:30  62.872211  528.766113  150.611633
#
# [5 rows x 441 columns]

# %%
def add_enhanced_features(df):
    """Add only the most significant features for return_ratio prediction"""
    print(f"DataFrame structure: {df.columns.nlevels} levels")
    print(f"Column levels: {[name for name in df.columns.names]}")
    
    # Store new columns as tuples first, then create a new DataFrame at the end
    new_columns = {}
    
    # Process each industry and symbol
    for industry in df.columns.levels[0]:  # Iterate over industries
        symbols = df[industry].columns  # Get symbols for this industry
        
        for symbol in symbols:  # Iterate over symbols within each industry
            try:
                print(f"Adding significant features for {industry} - {symbol}")
                
                # Get base price data
                price = df[(industry, symbol)]
                
                #--------------------------------------------------------------
                # 1. ESSENTIAL PRICE-BASED FEATURES
                #--------------------------------------------------------------
                
                # Original price data
                new_columns[(industry, symbol, 'price')] = price
                
                # Key return timeframes (most significant for prediction)
                new_columns[(industry, symbol, 'return_1d')] = price.pct_change(1)
                new_columns[(industry, symbol, 'return_5d')] = price.pct_change(5)
                new_columns[(industry, symbol, 'return_21d')] = price.pct_change(21)  # ~1 month
                
                # Log return (better statistical properties)
                new_columns[(industry, symbol, 'log_return')] = np.log(price / price.shift(1))
                
                #--------------------------------------------------------------
                # 2. KEY TECHNICAL INDICATORS
                #--------------------------------------------------------------
                
                # Most important moving averages
                new_columns[(industry, symbol, 'SMA_20')] = price.rolling(window=20).mean()
                new_columns[(industry, symbol, 'SMA_50')] = price.rolling(window=50).mean()
                
                # Exponential Moving Averages (EMA)
                new_columns[(industry, symbol, 'EMA_10')] = price.ewm(span=10, adjust=False).mean()
                new_columns[(industry, symbol, 'EMA_20')] = price.ewm(span=20, adjust=False).mean()
                new_columns[(industry, symbol, 'EMA_50')] = price.ewm(span=50, adjust=False).mean()
                
                # Weighted Moving Averages (WMA)
                # For WMA, more recent prices receive higher weights
                for window in [10, 20, 50]:
                    weights = np.arange(1, window + 1)
                    wma = price.rolling(window=window).apply(
                        lambda x: np.sum(weights * x) / weights.sum(), raw=True
                    )
                    new_columns[(industry, symbol, f'WMA_{window}')] = wma
                
                # Relative position to moving averages (stronger than raw MA values)
                new_columns[(industry, symbol, 'dist_from_sma20')] = (price - new_columns[(industry, symbol, 'SMA_20')]) / new_columns[(industry, symbol, 'SMA_20')]
                new_columns[(industry, symbol, 'dist_from_sma50')] = (price - new_columns[(industry, symbol, 'SMA_50')]) / new_columns[(industry, symbol, 'SMA_50')]
                new_columns[(industry, symbol, 'dist_from_ema20')] = (price - new_columns[(industry, symbol, 'EMA_20')]) / new_columns[(industry, symbol, 'EMA_20')]
                
                # MACD (strong momentum indicator)
                ema12 = price.ewm(span=12, adjust=False).mean()
                ema26 = price.ewm(span=26, adjust=False).mean()
                macd_line = ema12 - ema26
                signal_line = macd_line.ewm(span=9, adjust=False).mean()
                new_columns[(industry, symbol, 'MACD')] = macd_line
                new_columns[(industry, symbol, 'MACD_signal')] = signal_line
                
                # RSI (key overbought/oversold indicator)
                delta = price.diff()
                gain = delta.where(delta > 0, 0)
                loss = -delta.where(delta < 0, 0)
                avg_gain = gain.rolling(window=14).mean()
                avg_loss = loss.rolling(window=14).mean()
                rs = avg_gain / avg_loss.replace(0, np.finfo(float).eps)  # Avoid division by zero
                new_columns[(industry, symbol, 'RSI')] = 100 - (100 / (1 + rs))
                
                # Volatility (key risk measure)
                new_columns[(industry, symbol, 'volatility_20d')] = price.pct_change().rolling(20).std()
                
                # Bollinger Band Width (volatility measure)
                sma20 = new_columns[(industry, symbol, 'SMA_20')]
                std20 = price.rolling(window=20).std()
                upper_band = sma20 + (std20 * 2)
                lower_band = sma20 - (std20 * 2)
                new_columns[(industry, symbol, 'BB_width')] = (upper_band - lower_band) / sma20
                
                # Moving average crossovers (strong trend signals)
                new_columns[(industry, symbol, 'ema_cross_signal')] = (
                    (new_columns[(industry, symbol, 'EMA_10')] > new_columns[(industry, symbol, 'EMA_20')]).astype(int)
                )
                
                #--------------------------------------------------------------
                # 3. CALENDAR EFFECTS
                #--------------------------------------------------------------
                
                # Month-end effect (significant calendar anomaly)
                new_columns[(industry, symbol, 'is_month_end')] = pd.Series(df.index).dt.is_month_end.astype(int).values
                
                #--------------------------------------------------------------
                # 4. TARGET VARIABLE
                #--------------------------------------------------------------
                
                new_columns[(industry, symbol, 'return_ratio')] = price.pct_change()
                
            except Exception as e:
                print(f"Failed to process {industry} - {symbol}: {e}")
                continue
    
    # Create a new DataFrame with the proper MultiIndex structure
    result_df = pd.DataFrame(new_columns, index=df.index)
    
    # Ensure proper MultiIndex structure
    result_df.columns = pd.MultiIndex.from_tuples(result_df.columns)
    
    #--------------------------------------------------------------
    # 5. INDUSTRY-RELATIVE FEATURES (highly significant)
    #--------------------------------------------------------------
    
    # Calculate industry averages for each day
    industry_daily_returns = {}
    for industry in result_df.columns.levels[0]:
        industry_returns = pd.DataFrame()
        
        for symbol in result_df[industry].columns:
            if (industry, symbol, 'return_ratio') in result_df.columns:
                industry_returns[symbol] = result_df[(industry, symbol, 'return_ratio')]
        
        if not industry_returns.empty:
            industry_daily_returns[industry] = industry_returns.mean(axis=1)
    
    # Calculate relative performance metrics (most predictive cross-sectional features)
    for industry in industry_daily_returns:
        industry_avg = industry_daily_returns[industry]
        
        for symbol in result_df[industry].columns:
            try:
                if (industry, symbol, 'return_ratio') in result_df.columns:
                    symbol_return = result_df[(industry, symbol, 'return_ratio')]
                    
                    # Relative performance vs industry (key factor)
                    result_df[(industry, symbol, 'rel_to_industry')] = symbol_return - industry_avg
                    
                    # Return Z-score (statistical significance of returns)
                    result_df[(industry, symbol, 'return_z_score')] = (
                        (symbol_return - industry_avg) / industry_returns.std(axis=1).replace(0, np.finfo(float).eps)
                    )
                    
                    # Cumulative 10-day industry-relative performance (momentum)
                    result_df[(industry, symbol, 'cum_rel_perf_10d')] = (
                        (1 + (symbol_return - industry_avg)).rolling(10).apply(lambda x: np.prod(x) - 1, raw=True)
                    )
            except Exception as e:
                print(f"Failed to calculate relative features for {industry} - {symbol}: {e}")
    
    return result_df
# Apply the function to your DataFrame
enhanced_df = add_enhanced_features(merged_df)

# Save the enhanced DataFrame
enhanced_df.ffill().bfill().dropna().to_parquet(
    'stock_data/processed/merged_stock_data_with_enhanced_features.parquet',
    engine='pyarrow',
    index=True,
    compression='snappy'
)
# Out:
# DataFrame structure: 2 levels
# Column levels: ['Industry', 'Symbol']
# Adding significant features for Automobile and Auto Components - APOLLOTYRE
# Adding significant features for Automobile and Auto Components - ASAHIINDIA
# Adding significant features for Automobile and Auto Components - BAJAJ-AUTO
# Adding significant features for Automobile and Auto Components - BALKRISIND
# Adding significant features for Automobile and Auto Components - BHARATFORG
# Adding significant features for Automobile and Auto Components - BOSCHLTD
# Adding significant features for Automobile and Auto Components - CEATLTD
# Adding significant features for Automobile and Auto Components - CIEINDIA
# Adding significant features for Automobile and Auto Components - CRAFTSMAN
# Adding significant features for Automobile and Auto Components - EICHERMOT
# Adding significant features for Automobile and Auto Components - ENDURANCE
# Adding significant features for Automobile and Auto Components - EXIDEIND
# Adding significant features for Automobile and Auto Components - HEROMOTOCO
# Adding significant features for Automobile and Auto Components - JBMA
# Adding significant features for Automobile and Auto Components - JKTYRE
# Adding significant features for Automobile and Auto Components - MARUTI
# Adding significant features for Automobile and Auto Components - MINDACORP
# Adding significant features for Automobile and Auto Components - MOTHERSON
# Adding significant features for Automobile and Auto Components - MRF
# Adding significant features for Automobile and Auto Components - OLECTRA
# Adding significant features for Automobile and Auto Components - RKFORGE
# Adding significant features for Automobile and Auto Components - SCHAEFFLER
# Adding significant features for Automobile and Auto Components - SONACOMS
# Adding significant features for Automobile and Auto Components - SUNDRMFAST
# Adding significant features for Automobile and Auto Components - TATAMOTORS
# Adding significant features for Automobile and Auto Components - TIINDIA
# Adding significant features for Automobile and Auto Components - TVSMOTOR
# Adding significant features for Automobile and Auto Components - UNOMINDA
# Adding significant features for Automobile and Auto Components - VARROC
# Adding significant features for Automobile and Auto Components - ZFCVINDIA
# Adding significant features for Capital Goods - ABB
# Adding significant features for Capital Goods - ACE
# Adding significant features for Capital Goods - AIAENG
# Adding significant features for Capital Goods - APARINDS
# Adding significant features for Capital Goods - APLAPOLLO
# Adding significant features for Capital Goods - ASHOKLEY
# Adding significant features for Capital Goods - ASTRAL
# Adding significant features for Capital Goods - BDL
# Adding significant features for Capital Goods - BEL
# Adding significant features for Capital Goods - BEML
# Adding significant features for Capital Goods - BHEL
# Adding significant features for Capital Goods - CARBORUNIV
# Adding significant features for Capital Goods - CGPOWER
# Adding significant features for Capital Goods - COCHINSHIP
# Adding significant features for Capital Goods - CUMMINSIND
# Adding significant features for Capital Goods - DATAPATTNS
# Adding significant features for Capital Goods - ELECON
# Adding significant features for Capital Goods - ELGIEQUIP
# Adding significant features for Capital Goods - ESCORTS
# Adding significant features for Capital Goods - FINCABLES
# Adding significant features for Capital Goods - FINPIPE
# Adding significant features for Capital Goods - GPIL
# Adding significant features for Capital Goods - GRAPHITE
# Adding significant features for Capital Goods - GRINDWELL
# Adding significant features for Capital Goods - GRSE
# Adding significant features for Capital Goods - HAL
# Adding significant features for Capital Goods - HEG
# Adding significant features for Capital Goods - HONAUT
# Adding significant features for Capital Goods - INOXWIND
# Adding significant features for Capital Goods - JINDALSAW
# Adding significant features for Capital Goods - JWL
# Adding significant features for Capital Goods - KEI
# Adding significant features for Capital Goods - KIRLOSBROS
# Adding significant features for Capital Goods - KIRLOSENG
# Adding significant features for Capital Goods - KSB
# Adding significant features for Capital Goods - MAHSEAMLES
# Adding significant features for Capital Goods - MAZDOCK
# Adding significant features for Capital Goods - POLYCAB
# Adding significant features for Capital Goods - POWERINDIA
# Adding significant features for Capital Goods - PRAJIND
# Adding significant features for Capital Goods - RATNAMANI
# Adding significant features for Capital Goods - RHIM
# Adding significant features for Capital Goods - SCHNEIDER
# Adding significant features for Capital Goods - SHYAMMETL
# Adding significant features for Capital Goods - SIEMENS
# Adding significant features for Capital Goods - SKFINDIA
# Adding significant features for Capital Goods - SUPREMEIND
# Adding significant features for Capital Goods - SUZLON
# Adding significant features for Capital Goods - THERMAX
# Adding significant features for Capital Goods - TIMKEN
# Adding significant features for Capital Goods - TITAGARH
# Adding significant features for Capital Goods - TRITURBINE
# Adding significant features for Capital Goods - USHAMART
# Adding significant features for Capital Goods - WELCORP
# Adding significant features for Chemicals - AARTIIND
# Adding significant features for Chemicals - ALKYLAMINE
# Adding significant features for Chemicals - ATUL
# Adding significant features for Chemicals - BALAMINES
# Adding significant features for Chemicals - BASF
# Adding significant features for Chemicals - BAYERCROP
# Adding significant features for Chemicals - CHAMBLFERT
# Adding significant features for Chemicals - CHEMPLASTS
# Adding significant features for Chemicals - CLEAN
# Adding significant features for Chemicals - COROMANDEL
# Adding significant features for Chemicals - DEEPAKFERT
# Adding significant features for Chemicals - DEEPAKNTR
# Adding significant features for Chemicals - EIDPARRY
# Adding significant features for Chemicals - FACT
# Adding significant features for Chemicals - FINEORG
# Adding significant features for Chemicals - FLUOROCHEM
# Adding significant features for Chemicals - GNFC
# Adding significant features for Chemicals - GSFC
# Adding significant features for Chemicals - HSCL
# Adding significant features for Chemicals - JUBLINGREA
# Adding significant features for Chemicals - LINDEINDIA
# Adding significant features for Chemicals - NAVINFLUOR
# Adding significant features for Chemicals - PCBL
# Adding significant features for Chemicals - PIDILITIND
# Adding significant features for Chemicals - PIIND
# Adding significant features for Chemicals - RCF
# Adding significant features for Chemicals - SOLARINDS
# Adding significant features for Chemicals - SRF
# Adding significant features for Chemicals - SUMICHEM
# Adding significant features for Chemicals - TATACHEM
# Adding significant features for Chemicals - UPL
# Adding significant features for Chemicals - VINATIORGA
# Adding significant features for Construction - ENGINERSIN
# Adding significant features for Construction - GRINFRA
# Adding significant features for Construction - IRB
# Adding significant features for Construction - IRCON
# Adding significant features for Construction - KEC
# Adding significant features for Construction - KNRCON
# Adding significant features for Construction - LT
# Adding significant features for Construction - NBCC
# Adding significant features for Construction - NCC
# Adding significant features for Construction - PNCINFRA
# Adding significant features for Construction - RITES
# Adding significant features for Construction - RVNL
# Adding significant features for Construction - SWSOLAR
# Adding significant features for Construction - TECHNOE
# Adding significant features for Construction Materials - ACC
# Adding significant features for Construction Materials - AMBUJACEM
# Adding significant features for Construction Materials - BIRLACORPN
# Adding significant features for Construction Materials - DALBHARAT
# Adding significant features for Construction Materials - GRASIM
# Adding significant features for Construction Materials - INDIACEM
# Adding significant features for Construction Materials - JKCEMENT
# Adding significant features for Construction Materials - JKLAKSHMI
# Adding significant features for Construction Materials - NUVOCO
# Adding significant features for Construction Materials - RAMCOCEM
# Adding significant features for Construction Materials - SHREECEM
# Adding significant features for Construction Materials - ULTRACEMCO
# Adding significant features for Consumer Durables - AMBER
# Adding significant features for Consumer Durables - ASIANPAINT
# Adding significant features for Consumer Durables - BATAINDIA
# Adding significant features for Consumer Durables - BERGEPAINT
# Adding significant features for Consumer Durables - BLUESTARCO
# Adding significant features for Consumer Durables - CENTURYPLY
# Adding significant features for Consumer Durables - CERA
# Adding significant features for Consumer Durables - CROMPTON
# Adding significant features for Consumer Durables - DIXON
# Adding significant features for Consumer Durables - HAVELLS
# Adding significant features for Consumer Durables - KAJARIACER
# Adding significant features for Consumer Durables - KALYANKJIL
# Adding significant features for Consumer Durables - KANSAINER
# Adding significant features for Consumer Durables - METROBRAND
# Adding significant features for Consumer Durables - RAJESHEXPO
# Adding significant features for Consumer Durables - TITAN
# Adding significant features for Consumer Durables - VGUARD
# Adding significant features for Consumer Durables - VIPIND
# Adding significant features for Consumer Durables - VOLTAS
# Adding significant features for Consumer Durables - WHIRLPOOL
# Adding significant features for Consumer Services - ABFRL
# Adding significant features for Consumer Services - BLS
# Adding significant features for Consumer Services - CHALET
# Adding significant features for Consumer Services - DEVYANI
# Adding significant features for Consumer Services - DMART
# Adding significant features for Consumer Services - EASEMYTRIP
# Adding significant features for Consumer Services - EIHOTEL
# Adding significant features for Consumer Services - INDHOTEL
# Adding significant features for Consumer Services - INDIAMART
# Adding significant features for Consumer Services - IRCTC
# Adding significant features for Consumer Services - JUBLFOOD
# Adding significant features for Consumer Services - JUSTDIAL
# Adding significant features for Consumer Services - LEMONTREE
# Adding significant features for Consumer Services - NAUKRI
# Adding significant features for Consumer Services - NYKAA
# Adding significant features for Consumer Services - RTNINDIA
# Adding significant features for Consumer Services - SAPPHIRE
# Adding significant features for Consumer Services - TRENT
# Adding significant features for Consumer Services - WESTLIFE
# Adding significant features for Consumer Services - ZOMATO
# Adding significant features for Fast Moving Consumer Goods - AVANTIFEED
# Adding significant features for Fast Moving Consumer Goods - BALRAMCHIN
# Adding significant features for Fast Moving Consumer Goods - BBTC
# Adding significant features for Fast Moving Consumer Goods - BRITANNIA
# Adding significant features for Fast Moving Consumer Goods - CCL
# Adding significant features for Fast Moving Consumer Goods - COLPAL
# Adding significant features for Fast Moving Consumer Goods - DABUR
# Adding significant features for Fast Moving Consumer Goods - EMAMILTD
# Adding significant features for Fast Moving Consumer Goods - GAEL
# Adding significant features for Fast Moving Consumer Goods - GILLETTE
# Adding significant features for Fast Moving Consumer Goods - GODFRYPHLP
# Adding significant features for Fast Moving Consumer Goods - GODREJAGRO
# Adding significant features for Fast Moving Consumer Goods - GODREJCP
# Adding significant features for Fast Moving Consumer Goods - HINDUNILVR
# Adding significant features for Fast Moving Consumer Goods - ITC
# Adding significant features for Fast Moving Consumer Goods - JYOTHYLAB
# Adding significant features for Fast Moving Consumer Goods - MARICO
# Adding significant features for Fast Moving Consumer Goods - NESTLEIND
# Adding significant features for Fast Moving Consumer Goods - PATANJALI
# Adding significant features for Fast Moving Consumer Goods - PGHH
# Adding significant features for Fast Moving Consumer Goods - RADICO
# Adding significant features for Fast Moving Consumer Goods - RENUKA
# Adding significant features for Fast Moving Consumer Goods - TATACONSUM
# Adding significant features for Fast Moving Consumer Goods - TRIVENI
# Adding significant features for Fast Moving Consumer Goods - UBL
# Adding significant features for Fast Moving Consumer Goods - VBL
# Adding significant features for Financial Services - 360ONE
# Adding significant features for Financial Services - AAVAS
# Adding significant features for Financial Services - ABCAPITAL
# Adding significant features for Financial Services - ABSLAMC
# Adding significant features for Financial Services - ANANDRATHI
# Adding significant features for Financial Services - ANGELONE
# Adding significant features for Financial Services - APTUS
# Adding significant features for Financial Services - AUBANK
# Adding significant features for Financial Services - AXISBANK
# Adding significant features for Financial Services - BAJAJFINSV
# Adding significant features for Financial Services - BAJAJHLDNG
# Adding significant features for Financial Services - BAJFINANCE
# Adding significant features for Financial Services - BANDHANBNK
# Adding significant features for Financial Services - BANKBARODA
# Adding significant features for Financial Services - BANKINDIA
# Adding significant features for Financial Services - BSE
# Adding significant features for Financial Services - CAMS
# Adding significant features for Financial Services - CANBK
# Adding significant features for Financial Services - CANFINHOME
# Adding significant features for Financial Services - CDSL
# Adding significant features for Financial Services - CENTRALBK
# Adding significant features for Financial Services - CGCL
# Adding significant features for Financial Services - CHOLAFIN
# Adding significant features for Financial Services - CHOLAHLDNG
# Adding significant features for Financial Services - CREDITACC
# Adding significant features for Financial Services - CRISIL
# Adding significant features for Financial Services - CUB
# Adding significant features for Financial Services - EQUITASBNK
# Adding significant features for Financial Services - FEDERALBNK
# Adding significant features for Financial Services - GICRE
# Adding significant features for Financial Services - HDFCAMC
# Adding significant features for Financial Services - HDFCBANK
# Adding significant features for Financial Services - HDFCLIFE
# Adding significant features for Financial Services - HOMEFIRST
# Adding significant features for Financial Services - HUDCO
# Adding significant features for Financial Services - ICICIBANK
# Adding significant features for Financial Services - ICICIGI
# Adding significant features for Financial Services - ICICIPRULI
# Adding significant features for Financial Services - IDBI
# Adding significant features for Financial Services - IDFCFIRSTB
# Adding significant features for Financial Services - IEX
# Adding significant features for Financial Services - IFCI
# Adding significant features for Financial Services - IIFL
# Adding significant features for Financial Services - INDIANB
# Adding significant features for Financial Services - INDUSINDBK
# Adding significant features for Financial Services - IOB
# Adding significant features for Financial Services - IRFC
# Adding significant features for Financial Services - ISEC
# Adding significant features for Financial Services - JMFINANCIL
# Adding significant features for Financial Services - KARURVYSYA
# Adding significant features for Financial Services - KOTAKBANK
# Adding significant features for Financial Services - LICHSGFIN
# Adding significant features for Financial Services - LTF
# Adding significant features for Financial Services - MAHABANK
# Adding significant features for Financial Services - MANAPPURAM
# Adding significant features for Financial Services - MCX
# Adding significant features for Financial Services - MFSL
# Adding significant features for Financial Services - MOTILALOFS
# Adding significant features for Financial Services - MUTHOOTFIN
# Adding significant features for Financial Services - NAM-INDIA
# Adding significant features for Financial Services - NIACL
# Adding significant features for Financial Services - PAYTM
# Adding significant features for Financial Services - PEL
# Adding significant features for Financial Services - PFC
# Adding significant features for Financial Services - PNB
# Adding significant features for Financial Services - PNBHOUSING
# Adding significant features for Financial Services - POLICYBZR
# Adding significant features for Financial Services - POONAWALLA
# Adding significant features for Financial Services - RBLBANK
# Adding significant features for Financial Services - RECLTD
# Adding significant features for Financial Services - SAMMAANCAP
# Adding significant features for Financial Services - SBICARD
# Adding significant features for Financial Services - SBILIFE
# Adding significant features for Financial Services - SBIN
# Adding significant features for Financial Services - SHRIRAMFIN
# Adding significant features for Financial Services - STARHEALTH
# Adding significant features for Financial Services - SUNDARMFIN
# Adding significant features for Financial Services - TATAINVEST
# Adding significant features for Financial Services - UCOBANK
# Adding significant features for Financial Services - UJJIVANSFB
# Adding significant features for Financial Services - UNIONBANK
# Adding significant features for Financial Services - UTIAMC
# Adding significant features for Financial Services - YESBANK
# Adding significant features for Healthcare - ABBOTINDIA
# Adding significant features for Healthcare - AJANTPHARM
# Adding significant features for Healthcare - ALKEM
# Adding significant features for Healthcare - APLLTD
# Adding significant features for Healthcare - APOLLOHOSP
# Adding significant features for Healthcare - ASTERDM
# Adding significant features for Healthcare - ASTRAZEN
# Adding significant features for Healthcare - AUROPHARMA
# Adding significant features for Healthcare - BIOCON
# Adding significant features for Healthcare - CAPLIPOINT
# Adding significant features for Healthcare - CIPLA
# Adding significant features for Healthcare - DIVISLAB
# Adding significant features for Healthcare - DRREDDY
# Adding significant features for Healthcare - ERIS
# Adding significant features for Healthcare - FORTIS
# Adding significant features for Healthcare - GLAND
# Adding significant features for Healthcare - GLAXO
# Adding significant features for Healthcare - GLENMARK
# Adding significant features for Healthcare - GRANULES
# Adding significant features for Healthcare - IPCALAB
# Adding significant features for Healthcare - JBCHEPHARM
# Adding significant features for Healthcare - JUBLPHARMA
# Adding significant features for Healthcare - KIMS
# Adding significant features for Healthcare - LALPATHLAB
# Adding significant features for Healthcare - LAURUSLABS
# Adding significant features for Healthcare - LUPIN
# Adding significant features for Healthcare - MAXHEALTH
# Adding significant features for Healthcare - METROPOLIS
# Adding significant features for Healthcare - NATCOPHARM
# Adding significant features for Healthcare - NH
# Adding significant features for Healthcare - PFIZER
# Adding significant features for Healthcare - POLYMED
# Adding significant features for Healthcare - SANOFI
# Adding significant features for Healthcare - SPARC
# Adding significant features for Healthcare - SUNPHARMA
# Adding significant features for Healthcare - SUVENPHAR
# Adding significant features for Healthcare - SYNGENE
# Adding significant features for Healthcare - TORNTPHARM
# Adding significant features for Healthcare - VIJAYA
# Adding significant features for Healthcare - ZYDUSLIFE
# Adding significant features for Information Technology - AFFLE
# Adding significant features for Information Technology - BSOFT
# Adding significant features for Information Technology - COFORGE
# Adding significant features for Information Technology - CYIENT
# Adding significant features for Information Technology - HAPPSTMNDS
# Adding significant features for Information Technology - HCLTECH
# Adding significant features for Information Technology - INFY
# Adding significant features for Information Technology - INTELLECT
# Adding significant features for Information Technology - KPITTECH
# Adding significant features for Information Technology - LATENTVIEW
# Adding significant features for Information Technology - LTIM
# Adding significant features for Information Technology - LTTS
# Adding significant features for Information Technology - MAPMYINDIA
# Adding significant features for Information Technology - MASTEK
# Adding significant features for Information Technology - MPHASIS
# Adding significant features for Information Technology - NEWGEN
# Adding significant features for Information Technology - OFSS
# Adding significant features for Information Technology - PERSISTENT
# Adding significant features for Information Technology - SONATSOFTW
# Adding significant features for Information Technology - TANLA
# Adding significant features for Information Technology - TATAELXSI
# Adding significant features for Information Technology - TCS
# Adding significant features for Information Technology - TECHM
# Adding significant features for Information Technology - WIPRO
# Adding significant features for Information Technology - ZENSARTECH
# Adding significant features for Media Entertainment & Publication - NETWORK18
# Adding significant features for Media Entertainment & Publication - SAREGAMA
# Adding significant features for Media Entertainment & Publication - SUNTV
# Adding significant features for Media Entertainment & Publication - ZEEL
# Adding significant features for Metals & Mining - ADANIENT
# Adding significant features for Metals & Mining - GMDCLTD
# Adding significant features for Metals & Mining - HINDALCO
# Adding significant features for Metals & Mining - HINDCOPPER
# Adding significant features for Metals & Mining - HINDZINC
# Adding significant features for Metals & Mining - JINDALSTEL
# Adding significant features for Metals & Mining - JSL
# Adding significant features for Metals & Mining - JSWSTEEL
# Adding significant features for Metals & Mining - NATIONALUM
# Adding significant features for Metals & Mining - NMDC
# Adding significant features for Metals & Mining - SAIL
# Adding significant features for Metals & Mining - TATASTEEL
# Adding significant features for Metals & Mining - VEDL
# Adding significant features for Oil Gas & Consumable Fuels - ATGL
# Adding significant features for Oil Gas & Consumable Fuels - BPCL
# Adding significant features for Oil Gas & Consumable Fuels - CASTROLIND
# Adding significant features for Oil Gas & Consumable Fuels - CHENNPETRO
# Adding significant features for Oil Gas & Consumable Fuels - COALINDIA
# Adding significant features for Oil Gas & Consumable Fuels - GAIL
# Adding significant features for Oil Gas & Consumable Fuels - GSPL
# Adding significant features for Oil Gas & Consumable Fuels - GUJGASLTD
# Adding significant features for Oil Gas & Consumable Fuels - HINDPETRO
# Adding significant features for Oil Gas & Consumable Fuels - IGL
# Adding significant features for Oil Gas & Consumable Fuels - IOC
# Adding significant features for Oil Gas & Consumable Fuels - MGL
# Adding significant features for Oil Gas & Consumable Fuels - MRPL
# Adding significant features for Oil Gas & Consumable Fuels - OIL
# Adding significant features for Oil Gas & Consumable Fuels - ONGC
# Adding significant features for Oil Gas & Consumable Fuels - PETRONET
# Adding significant features for Oil Gas & Consumable Fuels - RELIANCE
# Adding significant features for Power - ADANIGREEN
# Adding significant features for Power - ADANIPOWER
# Adding significant features for Power - CESC
# Adding significant features for Power - JPPOWER
# Adding significant features for Power - JSWENERGY
# Adding significant features for Power - NHPC
# Adding significant features for Power - NLCINDIA
# Adding significant features for Power - NTPC
# Adding significant features for Power - POWERGRID
# Adding significant features for Power - SJVN
# Adding significant features for Power - TATAPOWER
# Adding significant features for Power - TORNTPOWER
# Adding significant features for Realty - ANANTRAJ
# Adding significant features for Realty - DBREALTY
# Adding significant features for Realty - DLF
# Adding significant features for Realty - GODREJPROP
# Adding significant features for Realty - LODHA
# Adding significant features for Realty - MAHLIFE
# Adding significant features for Realty - OBEROIRLTY
# Adding significant features for Realty - PRESTIGE
# Adding significant features for Realty - RAYMOND
# Adding significant features for Realty - SOBHA
# Adding significant features for Services - ADANIPORTS
# Adding significant features for Services - BLUEDART
# Adding significant features for Services - CONCOR
# Adding significant features for Services - ECLERX
# Adding significant features for Services - FSL
# Adding significant features for Services - GESHIP
# Adding significant features for Services - GMRAIRPORT
# Adding significant features for Services - GPPL
# Adding significant features for Services - INDIGO
# Adding significant features for Services - MMTC
# Adding significant features for Services - QUESS
# Adding significant features for Services - REDINGTON
# Adding significant features for Services - SCI
# Adding significant features for Telecommunication - BHARTIARTL
# Adding significant features for Telecommunication - HFCL
# Adding significant features for Telecommunication - IDEA
# Adding significant features for Telecommunication - INDUSTOWER
# Adding significant features for Telecommunication - ITI
# Adding significant features for Telecommunication - RAILTEL
# Adding significant features for Telecommunication - ROUTE
# Adding significant features for Telecommunication - TATACOMM
# Adding significant features for Telecommunication - TEJASNET
# Adding significant features for Telecommunication - TTML
# Adding significant features for Textiles - ALOKINDS
# Adding significant features for Textiles - KPRMILL
# Adding significant features for Textiles - PAGEIND
# Adding significant features for Textiles - TRIDENT
# Adding significant features for Textiles - VTL
# Adding significant features for Textiles - WELSPUNLIV

# %%
enhanced_df[100:105]
# Out:
#                           Automobile and Auto Components                      \
#                                               APOLLOTYRE
#                                                    price return_1d return_5d
# 2022-06-07 00:00:00+05:30                     202.934189 -0.023159 -0.034120
# 2022-06-08 00:00:00+05:30                     203.992661  0.005216 -0.035706
# 2022-06-09 00:00:00+05:30                     200.672974 -0.016274 -0.060162
# 2022-06-10 00:00:00+05:30                     192.830780 -0.039079 -0.081997
# 2022-06-13 00:00:00+05:30                     182.438721 -0.053892 -0.121816
#
#                                                                          \
#
#                           return_21d log_return      SMA_20      SMA_50
# 2022-06-07 00:00:00+05:30   0.091898  -0.023431  205.221900  195.929170
# 2022-06-08 00:00:00+05:30   0.066667   0.005202  206.008523  196.399700
# 2022-06-09 00:00:00+05:30   0.065934  -0.016407  206.612323  196.776895
# 2022-06-10 00:00:00+05:30   0.022449  -0.039864  206.600295  196.978963
# 2022-06-13 00:00:00+05:30  -0.055071  -0.055399  205.601981  197.001094
#
#                                                                ...  \
#                                                                ...
#                                EMA_10      EMA_20      EMA_50  ...
# 2022-06-07 00:00:00+05:30  207.655217  205.059527  199.674058  ...
# 2022-06-08 00:00:00+05:30  206.989297  204.957921  199.843415  ...
# 2022-06-09 00:00:00+05:30  205.840875  204.549830  199.875946  ...
# 2022-06-10 00:00:00+05:30  203.475403  203.433730  199.599665  ...
# 2022-06-13 00:00:00+05:30  199.650552  201.434206  198.926687  ...
#
#                                  Textiles                            \
#                                WELSPUNLIV
#                           dist_from_sma50 dist_from_ema20      MACD
# 2022-06-07 00:00:00+05:30       -0.134138       -0.011330 -3.126888
# 2022-06-08 00:00:00+05:30       -0.101663        0.017729 -2.671786
# 2022-06-09 00:00:00+05:30       -0.077121        0.036237 -2.157638
# 2022-06-10 00:00:00+05:30       -0.054479        0.051497 -1.611035
# 2022-06-13 00:00:00+05:30       -0.119497       -0.023352 -1.605437
#
#                                                                            \
#
#                           MACD_signal        RSI volatility_20d  BB_width
# 2022-06-07 00:00:00+05:30   -4.581981  52.819812       0.060777  0.171931
# 2022-06-08 00:00:00+05:30   -4.199942  61.142868       0.045471  0.170195
# 2022-06-09 00:00:00+05:30   -3.791481  51.079136       0.045085  0.181298
# 2022-06-10 00:00:00+05:30   -3.355392  55.871888       0.045082  0.199199
# 2022-06-13 00:00:00+05:30   -3.005401  53.859362       0.047568  0.189776
#
#
#
#                           ema_cross_signal is_month_end return_ratio
# 2022-06-07 00:00:00+05:30                0            0    -0.029696
# 2022-06-08 00:00:00+05:30                0            0     0.031317
# 2022-06-09 00:00:00+05:30                0            0     0.022084
# 2022-06-10 00:00:00+05:30                0            0     0.020257
# 2022-06-13 00:00:00+05:30                0            0    -0.073461
#
# [5 rows x 10584 columns]
